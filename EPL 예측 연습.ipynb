# %%
groups_folder_path = './cnn_practice/'
categories = ["ManCity","Arsenal","Brentford","Tottenham","Newcastle","LeedsUnited",
              "Chelsea","Brighton","AstonVilla","NottmForest","Bournemouth",
              "Liverpool","Fulham","Wolves","LeicesterCity","CrystalPalace",
              "Southampton","Everton","WestHam","ManUnited"]

num_classes = len(categories)

# %%
# 원본 이미지 넘버링하기

import os
import glob

path = "./cnn_practice/"
ManCity = glob.glob(path+"/ManCity logo" + '/*')
Arsenal = glob.glob(path+"/Arsenal logo" + '/*')
Brentford = glob.glob(path+"/Brentford logo" + '/*')
Tottenham = glob.glob(path+"/Tottenham logo" + '/*')
Newcastle = glob.glob(path+"/Newcastle logo" + '/*')
LeedsUnited = glob.glob(path+"/LeedsUnited logo" + '/*')
Chelsea = glob.glob(path+"/Chelsea logo" + '/*')
Brighton = glob.glob(path+"/Brighton logo" + '/*')
AstonVilla = glob.glob(path+"/AstonVilla logo" + '/*')
NottmForest = glob.glob(path+"/NottmForest logo" + '/*')
Bournemouth = glob.glob(path+"/Bournemouth logo" + '/*')
Liverpool = glob.glob(path+"/Liverpool logo" + '/*')
Fulham = glob.glob(path+"/Fulham logo" + '/*')
Wolves= glob.glob(path+"/Wolves logo" + '/*')
LeicesterCity= glob.glob(path+"/LeicesterCity logo" + '/*')
CrystalPalace = glob.glob(path+"/CrystalPalace logo" + '/*')
Southampton = glob.glob(path+"/Southampton logo" + '/*')
Everton = glob.glob(path+"/Everton logo" + '/*')
WestHam = glob.glob(path+"/WestHam logo" + '/*')
ManUnited = glob.glob(path+"/ManUnited logo" + '/*')




def rename(files):

  if 'ManCity' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/ManCity logo", 'ManCity_' + '{0:03d}.jpg'.format(i)))
     ManCity = glob.glob(path+"/ManCity logo" + '/*')    
     print("ManCity {}번째 이미지까지 성공".format(i+1))

  elif 'Arsenal' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Arsenal logo", 'Arsenal_' + '{0:03d}.jpg'.format(i)))
     Arsenal = glob.glob(path+"/Arsenal logo"+'/*')
     print("Arsenal {}번째 이미지까지 성공".format(i+1))


  elif 'Brentford' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Brentford logo", 'Brentford_' + '{0:03d}.jpg'.format(i)))
     Brentford = glob.glob(path+"/Brentford logo"+'/*')
     print("Brentford {}번째 이미지까지 성공".format(i+1))

  elif 'Tottenham' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Tottenham logo", 'Tottenham_' + '{0:03d}.jpg'.format(i)))
     Tottenham = glob.glob(path+"/Tottenham logo"+'/*')
     print("Tottenham {}번째 이미지까지 성공".format(i+1))

  elif 'Newcastle' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Newcastle logo", 'Newcastle_' + '{0:03d}.jpg'.format(i)))
     Newcastle = glob.glob(path+"/Newcastle logo"+'/*')
     print("Newcastle {}번째 이미지까지 성공".format(i+1))
        
  elif 'LeedsUnited' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/LeedsUnited logo", 'LeedsUnited_' + '{0:03d}.jpg'.format(i)))
     LeedsUnited = glob.glob(path+"/LeedsUnited logo"+'/*')
     print("LeedsUnited {}번째 이미지까지 성공".format(i+1))

  elif 'Chelsea' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Chelsea logo", 'Chelsea_' + '{0:03d}.jpg'.format(i)))
     Chelsea = glob.glob(path+"/Chelsea logo"+'/*')
     print("Chelsea {}번째 이미지까지 성공".format(i+1))
        
  elif 'Brighton' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Brighton logo", 'Brighton_' + '{0:03d}.jpg'.format(i)))
     Brighton = glob.glob(path+"/Brighton logo"+'/*')
     print("Brighton {}번째 이미지까지 성공".format(i+1))
        
  elif 'AstonVilla' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/AstonVilla logo", 'AstonVilla_' + '{0:03d}.jpg'.format(i)))
     AstonVilla = glob.glob(path+"/AstonVilla logo"+'/*')
     print("AstonVilla {}번째 이미지까지 성공".format(i+1))
        
  elif 'NottmForest' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/NottmForest logo", 'NottmForest_' + '{0:03d}.jpg'.format(i)))
     NottmForest = glob.glob(path+"/NottmForest logo"+'/*')
     print("NottmForest {}번째 이미지까지 성공".format(i+1))
        
  elif 'Bournemouth' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Bournemouth logo", 'Bournemouth_' + '{0:03d}.jpg'.format(i)))
     Bournemouth = glob.glob(path+"/Bournemouth logo"+'/*')
     print("Bournemouth {}번째 이미지까지 성공".format(i+1))
        
  elif 'Liverpool' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Liverpool logo", 'Liverpool_' + '{0:03d}.jpg'.format(i)))
     Liverpool = glob.glob(path+"/Liverpool logo"+'/*')
     print("Liverpool {}번째 이미지까지 성공".format(i+1))
        
  elif 'Fulham' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Fulham logo", 'Fulham_' + '{0:03d}.jpg'.format(i)))
     Fulham = glob.glob(path+"/Fulham logo"+'/*')
     print("Fulham {}번째 이미지까지 성공".format(i+1))

  elif 'Wolves' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Wolves logo", 'Wolves_' + '{0:03d}.jpg'.format(i)))
     Wolves = glob.glob(path+"/Wolves logo"+'/*')
     print("Wolves {}번째 이미지까지 성공".format(i+1))
        
  elif 'LeicesterCity' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/LeicesterCity logo", 'LeicesterCity_' + '{0:03d}.jpg'.format(i)))
     LeicesterCity = glob.glob(path+"/LeicesterCity logo"+'/*')
     print("LeicesterCity {}번째 이미지까지 성공".format(i+1))
        
  elif 'CrystalPalace' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/CrystalPalace logo", 'CrystalPalace_' + '{0:03d}.jpg'.format(i)))
     CrystalPalace = glob.glob(path+"/CrystalPalace logo"+'/*')
     print("CrystalPalace {}번째 이미지까지 성공".format(i+1))
        
  elif 'Southampton' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Southampton logo", 'Southampton_' + '{0:03d}.jpg'.format(i)))
     Southampton = glob.glob(path+"/Southampton logo"+'/*')
     print("Southampton {}번째 이미지까지 성공".format(i+1))
        
  elif 'Everton' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Everton logo", 'Everton_' + '{0:03d}.jpg'.format(i)))
     Everton = glob.glob(path+"/Everton logo"+'/*')
     print("Everton {}번째 이미지까지 성공".format(i+1))
        
  elif 'WestHam' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/WestHam logo", 'WestHam_' + '{0:03d}.jpg'.format(i)))
     WestHam = glob.glob(path+"/WestHam logo"+'/*')
     print("WestHam {}번째 이미지까지 성공".format(i+1))

  elif 'ManUnited' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/ManUnited logo", 'ManUnited_' + '{0:03d}.jpg'.format(i)))
     ManUnited = glob.glob(path+"/ManUnited logo"+'/*')
     print("ManUnited {}번째 이미지까지 성공".format(i+1))

# %%
rename(ManCity)
rename(Arsenal)
rename(Brentford)
rename(Tottenham)
rename(Newcastle)
rename(LeedsUnited)
rename(Chelsea)
rename(Brighton)
rename(AstonVilla)
rename(NottmForest)
rename(Bournemouth)
rename(Liverpool)
rename(Fulham)
rename(Wolves)
rename(LeicesterCity)
rename(CrystalPalace)
rename(Southampton)
rename(Everton)
rename(WestHam)
rename(ManUnited)
# Out:
# ManCity 104번째 이미지까지 성공
# Arsenal 183번째 이미지까지 성공
# Brentford 26번째 이미지까지 성공
# Tottenham 190번째 이미지까지 성공
# Newcastle 74번째 이미지까지 성공
# LeedsUnited 22번째 이미지까지 성공
# Chelsea 143번째 이미지까지 성공
# Brighton 48번째 이미지까지 성공
# AstonVilla 31번째 이미지까지 성공
# NottmForest 29번째 이미지까지 성공
# Bournemouth 27번째 이미지까지 성공
# Liverpool 114번째 이미지까지 성공
# Fulham 24번째 이미지까지 성공
# Wolves 30번째 이미지까지 성공
# LeicesterCity 164번째 이미지까지 성공
# CrystalPalace 31번째 이미지까지 성공
# Southampton 33번째 이미지까지 성공
# Everton 162번째 이미지까지 성공
# WestHam 133번째 이미지까지 성공
# ManUnited 236번째 이미지까지 성공

# %%
# 이미지 리스트 정렬

ManCity = sorted(glob.glob(path+"/ManCity logo" + '/*'))
Arsenal = sorted(glob.glob(path+"/Arsenal logo" + '/*'))
Brentford = sorted(glob.glob(path+"/Brentford logo" + '/*'))
Tottenham = sorted(glob.glob(path+"/Tottenham logo" + '/*'))
Newcastle = sorted(glob.glob(path+"/Newcastle logo" + '/*'))
LeedsUnited = sorted(glob.glob(path+"/LeedsUnited logo" + '/*'))
Chelsea = sorted(glob.glob(path+"/Chelsea logo" + '/*'))
Brighton = sorted(glob.glob(path+"/Brighton logo" + '/*'))
AstonVilla = sorted(glob.glob(path+"/AstonVilla logo" + '/*'))
NottmForest = sorted(glob.glob(path+"/NottmForest logo" + '/*'))
Bournemouth = sorted(glob.glob(path+"/Bournemouth logo" + '/*'))
Liverpool = sorted(glob.glob(path+"/Liverpool logo" + '/*'))
Fulham = sorted(glob.glob(path+"/Fulham logo" + '/*'))
Wolves= sorted(glob.glob(path+"/Wolves logo" + '/*'))
LeicesterCity= sorted(glob.glob(path+"/LeicesterCity logo" + '/*'))
CrystalPalace = sorted(glob.glob(path+"/CrystalPalace logo" + '/*'))
Southampton = sorted(glob.glob(path+"/Southampton logo" + '/*'))
Everton = sorted(glob.glob(path+"/Everton logo" + '/*'))
WestHam = sorted(glob.glob(path+"/WestHam logo" + '/*'))
ManUnited = sorted(glob.glob(path+"/ManUnited logo" + '/*'))

print('ManCity 이미지 개수: {}\nArsenal 이미지 개수: {}\nBrentford 이미지 개수: {}\nTottenham 이미지 개수: {}\nNewcastle 이미지 개수: {}\nLeedsUnited 이미지 개수: {}\nChelsea 이미지 개수: {}\nBrighton 이미지 개수: {}\nAstonVilla 이미지 개수: {}\nNottmForest 이미지 개수: {}\nBournemouth 이미지 개수: {}\nLiverpool 이미지 개수: {}\nFulham 이미지 개수: {}\nWolves 이미지 개수: {}\nLeicesterCity 이미지 개수: {}\nCrystalPalace 이미지 개수: {}\nSouthampton 이미지 개수: {}\nEverton 이미지 개수: {}\nWestHam 이미지 개수: {}\nManUnited 이미지 개수: {}'.format(len(ManCity),len(Arsenal),len(Brentford),len(Tottenham),len(Newcastle),len(LeedsUnited),len(Chelsea),len(Brighton),len(AstonVilla),len(NottmForest),len(Bournemouth),len(Liverpool),len(Fulham),len(Wolves),len(LeicesterCity),len(CrystalPalace),len(Southampton),len(Everton),len(WestHam),len(ManUnited)))
# Out:
# ManCity 이미지 개수: 104
# Arsenal 이미지 개수: 183
# Brentford 이미지 개수: 26
# Tottenham 이미지 개수: 190
# Newcastle 이미지 개수: 74
# LeedsUnited 이미지 개수: 22
# Chelsea 이미지 개수: 143
# Brighton 이미지 개수: 48
# AstonVilla 이미지 개수: 31
# NottmForest 이미지 개수: 29
# Bournemouth 이미지 개수: 27
# Liverpool 이미지 개수: 114
# Fulham 이미지 개수: 24
# Wolves 이미지 개수: 30
# LeicesterCity 이미지 개수: 164
# CrystalPalace 이미지 개수: 31
# Southampton 이미지 개수: 33
# Everton 이미지 개수: 162
# WestHam 이미지 개수: 133
# ManUnited 이미지 개수: 236

# %%
whole_sum = len(paris)+len(manchest)

print('전체 이미지 개수 : {}\n\nparis 이미지 비율 : {:.2f}%\nmanchest 이미지 비율 : {:.2f}%\n'.format(whole_sum, 100*len(paris)/whole_sum, 100*len(manchest)/whole_sum))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 whole_sum = len(paris)+len(manchest)
#       3 print('전체 이미지 개수 : {}\n\nparis 이미지 비율 : {:.2f}%\nmanchest 이미지 비율 : {:.2f}%\n'.format(whole_sum, 100*len(paris)/whole_sum, 100*len(manchest)/whole_sum))
#
# NameError: name 'paris' is not defined

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import cv2
# %matplotlib inline

# cv2를 이용해 이미지를 읽는 함수 정의
def read_img(file_path):
    img_arr = cv2.imread(file_path)
    return cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB) # cvtColor로 BGR을 RGB로 바꿔줌

# %%
# 각 이미지 폴더에서 3개씩 랜덤으로 이미지 시각화 하기

# 이미지 array 준비
import random
img_arrs = []
img_num = range(0,22)

for i in random.sample(img_num,1):
    
    img_arrs.append(read_img(ManCity[i]))
    img_arrs.append(read_img(Arsenal[i]))
    img_arrs.append(read_img(Brentford[i]))
    img_arrs.append(read_img(Tottenham[i]))
    img_arrs.append(read_img(Newcastle[i]))
    img_arrs.append(read_img(LeedsUnited[i]))
    img_arrs.append(read_img(Chelsea[i]))
    img_arrs.append(read_img(Brighton[i]))
    img_arrs.append(read_img(AstonVilla[i]))
    img_arrs.append(read_img(NottmForest[i]))
    img_arrs.append(read_img(Bournemouth[i]))
    img_arrs.append(read_img(Liverpool[i]))
    img_arrs.append(read_img(Fulham[i]))
    img_arrs.append(read_img(Wolves[i]))
    img_arrs.append(read_img(LeicesterCity[i]))
    img_arrs.append(read_img(CrystalPalace[i]))
    img_arrs.append(read_img(Southampton[i]))
    img_arrs.append(read_img(Everton[i]))
    img_arrs.append(read_img(WestHam[i]))
    img_arrs.append(read_img(ManUnited[i]))

# %%
print("총 {}개의 이미지 ".format(len(img_arrs)))

# %%
rows = 2 # 2개씩 샘플링 했으므로
columns = 10

# 그림판 설정
fig, axes = plt.subplots(nrows=rows, ncols=columns, figsize=(columns*10, rows*10))

# 각 판에 이미지 출력
for num in range(1, rows*columns+1): # 1번 부터 15번 까지
    
    fig.add_subplot(rows, columns, num) # 원하는 위치 번호(num)를 입력
    idx = num - 1 # 인덱스
    
    plt.imshow(img_arrs[idx], aspect='auto')
    plt.xlabel(f'{img_arrs[idx].shape}', fontsize=30)

fig.tight_layout() # 이미지 사이 간격 조정



# 제목 설정
cols = ['ManCity','Arsenal','Brentford','Tottenham','Newcastle','LeedsUnited','Chelsea','Brighton','AstonVilla','NottmForest','Bournemouth','Liverpool','Fulham','Wolves','LeicesterCity','CrystalPalace','Southampton','Everton','WestHam', 'ManUnited']

for folder_idx, ax in enumerate(axes[0]):
    ax.set_title(cols[folder_idx])

# xtick, ytick 제거
for idx, ax in enumerate(axes.flat):
    ax.set_xticks([])
    ax.set_yticks([])

# %%
# 비율이 작은 test로 빠르게 split

import math

ManCity_test_count = round(len(ManCity)*0.2)
Arsenal_test_count = round(len(Arsenal)*0.2)
Brentford_test_count = round(len(Brentford)*0.2)
Tottenham_test_count = round(len(Tottenham)*0.2)
Newcastle_test_count = round(len(Newcastle)*0.2)
LeedsUnited_test_count = round(len(LeedsUnited)*0.2)
Chelsea_test_count = round(len(Chelsea)*0.2)
Brighton_test_count = round(len(Brighton)*0.2)
AstonVilla_test_count = round(len(AstonVilla)*0.2)
NottmForest_test_count = round(len(NottmForest)*0.2)
Bournemouth_test_count = round(len(Bournemouth)*0.2)
Liverpool_test_count = round(len(Liverpool)*0.2)
Fulham_test_count = round(len(Fulham)*0.2)
Wolves_test_count = round(len(Wolves)*0.2)
LeicesterCity_test_count = round(len(LeicesterCity)*0.2)
CrystalPalace_test_count = round(len(CrystalPalace)*0.2)
Southampton_test_count = round(len(Southampton)*0.2)
Everton_test_count = round(len(Everton)*0.2)
WestHam_test_count = round(len(WestHam)*0.2)
ManUnited_test_count = round(len(ManUnited)*0.2)

print('ManCity test파일에 들어갈 이미지 개수 : {}/{}'.format(ManCity_test_count,len(ManCity)))
print('Arsenal test파일에 들어갈 이미지 개수 : {}/{}'.format(Arsenal_test_count,len(Arsenal)))
print('Brentford test파일에 들어갈 이미지 개수 : {}/{}'.format(Brentford_test_count,len(Brentford)))
print('Tottenham test파일에 들어갈 이미지 개수 : {}/{}'.format(Tottenham_test_count,len(Tottenham)))
print('Newcastle test파일에 들어갈 이미지 개수 : {}/{}'.format(Newcastle_test_count,len(Newcastle)))
print('LeedsUnited test파일에 들어갈 이미지 개수 : {}/{}'.format(LeedsUnited_test_count,len(LeedsUnited)))
print('Chelsea test파일에 들어갈 이미지 개수 : {}/{}'.format(Chelsea_test_count,len(Chelsea)))
print('Brighton test파일에 들어갈 이미지 개수 : {}/{}'.format(Brighton_test_count,len(Brighton)))
print('AstonVilla test파일에 들어갈 이미지 개수 : {}/{}'.format(AstonVilla_test_count,len(AstonVilla)))
print('NottmForest test파일에 들어갈 이미지 개수 : {}/{}'.format(NottmForest_test_count,len(NottmForest)))
print('Bournemouth test파일에 들어갈 이미지 개수 : {}/{}'.format(Bournemouth_test_count,len(Bournemouth)))
print('Liverpool test파일에 들어갈 이미지 개수 : {}/{}'.format(Liverpool_test_count,len(Liverpool)))
print('Fulham test파일에 들어갈 이미지 개수 : {}/{}'.format(Fulham_test_count,len(Fulham)))
print('Wolves test파일에 들어갈 이미지 개수 : {}/{}'.format(Wolves_test_count,len(Wolves)))
print('LeicesterCity test파일에 들어갈 이미지 개수 : {}/{}'.format(LeicesterCity_test_count,len(LeicesterCity)))
print('CrystalPalace test파일에 들어갈 이미지 개수 : {}/{}'.format(CrystalPalace_test_count,len(CrystalPalace)))
print('Southampton test파일에 들어갈 이미지 개수 : {}/{}'.format(Southampton_test_count,len(Southampton)))
print('Everton test파일에 들어갈 이미지 개수 : {}/{}'.format(Everton_test_count,len(Everton)))
print('WestHam test파일에 들어갈 이미지 개수 : {}/{}'.format(WestHam_test_count,len(WestHam)))
print('ManUnited test파일에 들어갈 이미지 개수 : {}/{}'.format(ManUnited_test_count,len(ManUnited)))
# Out:
# ManCity test파일에 들어갈 이미지 개수 : 21/104
# Arsenal test파일에 들어갈 이미지 개수 : 37/183
# Brentford test파일에 들어갈 이미지 개수 : 5/26
# Tottenham test파일에 들어갈 이미지 개수 : 38/190
# Newcastle test파일에 들어갈 이미지 개수 : 15/74
# LeedsUnited test파일에 들어갈 이미지 개수 : 4/22
# Chelsea test파일에 들어갈 이미지 개수 : 29/143
# Brighton test파일에 들어갈 이미지 개수 : 10/48
# AstonVilla test파일에 들어갈 이미지 개수 : 6/31
# NottmForest test파일에 들어갈 이미지 개수 : 6/29
# Bournemouth test파일에 들어갈 이미지 개수 : 5/27
# Liverpool test파일에 들어갈 이미지 개수 : 23/114
# Fulham test파일에 들어갈 이미지 개수 : 5/24
# Wolves test파일에 들어갈 이미지 개수 : 6/30
# LeicesterCity test파일에 들어갈 이미지 개수 : 33/164
# CrystalPalace test파일에 들어갈 이미지 개수 : 6/31
# Southampton test파일에 들어갈 이미지 개수 : 7/33
# Everton test파일에 들어갈 이미지 개수 : 32/162
# WestHam test파일에 들어갈 이미지 개수 : 27/133
# ManUnited test파일에 들어갈 이미지 개수 : 47/236

# %%
import shutil

def split( img_list, test_count, train_path, test_path):
  
  test_files=[]
  for i in random.sample( img_list, test_count ):
    test_files.append(i)

  # 차집합으로 train/test 리스트 생성하기
  train_files = [x for x in img_list if x not in test_files]

  for k in train_files:
    shutil.copy(k, train_path)
  
  for c in test_files:
    shutil.copy(c, test_path)

  print('train 폴더 이미지 개수 : {}\ntest 폴더 이미지 개수 : {}'.format(len(glob.glob(train_path+'/*')),len(glob.glob(test_path+'/*'))))

# %%
# 돌고래 파일
ManCity_train_path='./cnn_practice/train/ManCity/'
ManCity_test_path='./cnn_practice/test/ManCity/'
Arsenal_train_path='./cnn_practice/train/Arsenal/'
Arsenal_test_path='./cnn_practice/test/Arsenal/'
Brentford_train_path='./cnn_practice/train/Brentford/'
Brentford_test_path='./cnn_practice/test/Brentford/'
Tottenham_train_path='./cnn_practice/train/Tottenham/'
Tottenham_test_path='./cnn_practice/test/Tottenham/'
Newcastle_train_path='./cnn_practice/train/Newcastle/'
Newcastle_test_path='./cnn_practice/test/Newcastle/'
LeedsUnited_train_path='./cnn_practice/train/LeedsUnited/'
LeedsUnited_test_path='./cnn_practice/test/LeedsUnited/'
Chelsea_train_path='./cnn_practice/train/Chelsea/'
Chelsea_test_path='./cnn_practice/test/Chelsea/'
Brighton_train_path='./cnn_practice/train/Brighton/'
Brighton_test_path='./cnn_practice/test/Brighton/'
AstonVilla_train_path='./cnn_practice/train/AstonVilla/'
AstonVilla_test_path='./cnn_practice/test/AstonVilla/'
NottmForest_train_path='./cnn_practice/train/NottmForest/'
NottmForest_test_path='./cnn_practice/test/NottmForest/'
Bournemouth_train_path='./cnn_practice/train/Bournemouth/'
Bournemouth_test_path='./cnn_practice/test/Bournemouth/'
Liverpool_train_path='./cnn_practice/train/Liverpool/'
Liverpool_test_path='./cnn_practice/test/Liverpool/'
Fulham_train_path='./cnn_practice/train/Fulham/'
Fulham_test_path='./cnn_practice/test/Fulham/'
Wolves_train_path='./cnn_practice/train/Wolves/'
Wolves_test_path='./cnn_practice/test/Wolves/'
LeicesterCity_train_path='./cnn_practice/train/LeicesterCity/'
LeicesterCity_test_path='./cnn_practice/test/LeicesterCity/'
CrystalPalace_train_path='./cnn_practice/train/CrystalPalace/'
CrystalPalace_test_path='./cnn_practice/test/CrystalPalace/'
Southampton_train_path='./cnn_practice/train/Southampton/'
Southampton_test_path='./cnn_practice/test/Southampton/'
Everton_train_path='./cnn_practice/train/Everton/'
Everton_test_path='./cnn_practice/test/Everton/'
WestHam_train_path='./cnn_practice/train/WestHam/'
WestHam_test_path='./cnn_practice/test/WestHam/'
ManUnited_train_path='./cnn_practice/train/ManUnited/'
ManUnited_test_path='./cnn_practice/test/ManUnited/'



split(ManCity, ManCity_test_count, ManCity_train_path, ManCity_test_path)
split(Arsenal, Arsenal_test_count, Arsenal_train_path, Arsenal_test_path)
split(Brentford, Brentford_test_count, Brentford_train_path, Brentford_test_path)
split(Tottenham, Tottenham_test_count, Tottenham_train_path, Tottenham_test_path)
split(Newcastle, Newcastle_test_count, Newcastle_train_path, Newcastle_test_path)
split(LeedsUnited, LeedsUnited_test_count, LeedsUnited_train_path, LeedsUnited_test_path)
split(Chelsea, Chelsea_test_count, Chelsea_train_path, Chelsea_test_path)
split(Brighton, Brighton_test_count, Brighton_train_path, Brighton_test_path)
split(AstonVilla, AstonVilla_test_count, AstonVilla_train_path, AstonVilla_test_path)
split(NottmForest, NottmForest_test_count, NottmForest_train_path, NottmForest_test_path)
split(Bournemouth, Bournemouth_test_count, Bournemouth_train_path, Bournemouth_test_path)
split(Liverpool, Liverpool_test_count, Liverpool_train_path, Liverpool_test_path)
split(Fulham, Fulham_test_count, Fulham_train_path, Fulham_test_path)
split(Wolves, Wolves_test_count, Wolves_train_path, Wolves_test_path)
split(LeicesterCity, LeicesterCity_test_count, LeicesterCity_train_path, LeicesterCity_test_path)
split(CrystalPalace, CrystalPalace_test_count, CrystalPalace_train_path, CrystalPalace_test_path)
split(Southampton, Southampton_test_count, Southampton_train_path, Southampton_test_path)
split(Everton, Everton_test_count, Everton_train_path, Everton_test_path)
split(WestHam, WestHam_test_count, WestHam_train_path, WestHam_test_path)
split(ManUnited, ManUnited_test_count, ManUnited_train_path, ManUnited_test_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 45>()
#      40 ManUnited_train_path='./cnn_practice/train/ManUnited/'
#      41 ManUnited_test_path='./cnn_practice/test/ManUnited/'
# ---> 45 split(ManCity, ManCity_test_count, ManCity_train_path, ManCity_test_path)
#      46 split(Arsenal, Arsenal_test_count, Arsenal_train_path, Arsenal_test_path)
#      47 split(Brentford, Brentford_test_count, Brentford_train_path, Brentford_test_path)
#
# Input In [7], in split(img_list, test_count, train_path, test_path)
#       3 def split( img_list, test_count, train_path, test_path):
#       5   test_files=[]
# ----> 6   for i in random.sample( img_list, test_count ):
#       7     test_files.append(i)
#       9   # 차집합으로 train/test 리스트 생성하기
#
# NameError: name 'random' is not defined

# %%
def rename_2(files):

  if 'ManCity' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/ManCity", 'ManCity_' + '{0:03d}.jpg'.format(i)))
     ManCity = glob.glob(path+"/ManCity" + '/*')    
     print("ManCity {}번째 이미지까지 성공".format(i+1))

  elif 'Arsenal' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Arsenal", 'Arsenal_' + '{0:03d}.jpg'.format(i)))
     Arsenal = glob.glob(path+"/Arsenal"+'/*')
     print("Arsenal {}번째 이미지까지 성공".format(i+1))


  elif 'Brentford' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Brentford", 'Brentford_' + '{0:03d}.jpg'.format(i)))
     Brentford = glob.glob(path+"/Brentford"+'/*')
     print("Brentford {}번째 이미지까지 성공".format(i+1))

  elif 'Tottenham' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Tottenham", 'Tottenham_' + '{0:03d}.jpg'.format(i)))
     Tottenham = glob.glob(path+"/Tottenham"+'/*')
     print("Tottenham {}번째 이미지까지 성공".format(i+1))

  elif 'Newcastle' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Newcastle", 'Newcastle_' + '{0:03d}.jpg'.format(i)))
     Newcastle = glob.glob(path+"/Newcastle"+'/*')
     print("Newcastle {}번째 이미지까지 성공".format(i+1))
        
  elif 'LeedsUnited' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/LeedsUnited", 'LeedsUnited_' + '{0:03d}.jpg'.format(i)))
     LeedsUnited = glob.glob(path+"/LeedsUnited"+'/*')
     print("LeedsUnited {}번째 이미지까지 성공".format(i+1))

  elif 'Chelsea' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Chelsea", 'Chelsea_' + '{0:03d}.jpg'.format(i)))
     Chelsea = glob.glob(path+"/Chelsea"+'/*')
     print("Chelsea {}번째 이미지까지 성공".format(i+1))
        
  elif 'Brighton' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Brighton", 'Brighton_' + '{0:03d}.jpg'.format(i)))
     Brighton = glob.glob(path+"/Brighton"+'/*')
     print("Brighton {}번째 이미지까지 성공".format(i+1))
        
  elif 'AstonVilla' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/AstonVilla", 'AstonVilla_' + '{0:03d}.jpg'.format(i)))
     AstonVilla = glob.glob(path+"/AstonVilla"+'/*')
     print("AstonVilla {}번째 이미지까지 성공".format(i+1))
        
  elif 'NottmForest' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/NottmForest", 'NottmForest_' + '{0:03d}.jpg'.format(i)))
     NottmForest = glob.glob(path+"/NottmForest"+'/*')
     print("NottmForest {}번째 이미지까지 성공".format(i+1))
        
  elif 'Bournemouth' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Bournemouth", 'Bournemouth_' + '{0:03d}.jpg'.format(i)))
     Bournemouth = glob.glob(path+"/Bournemouth"+'/*')
     print("Bournemouth {}번째 이미지까지 성공".format(i+1))
        
  elif 'Liverpool' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Liverpool", 'Liverpool_' + '{0:03d}.jpg'.format(i)))
     Liverpool = glob.glob(path+"/Liverpool"+'/*')
     print("Liverpool {}번째 이미지까지 성공".format(i+1))
        
  elif 'Fulham' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Fulham", 'Fulham_' + '{0:03d}.jpg'.format(i)))
     Fulham = glob.glob(path+"/Fulham"+'/*')
     print("Fulham {}번째 이미지까지 성공".format(i+1))

  elif 'Wolves' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Wolves", 'Wolves_' + '{0:03d}.jpg'.format(i)))
     Wolves = glob.glob(path+"/Wolves"+'/*')
     print("Wolves {}번째 이미지까지 성공".format(i+1))
        
  elif 'LeicesterCity' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/LeicesterCity", 'LeicesterCity_' + '{0:03d}.jpg'.format(i)))
     LeicesterCity = glob.glob(path+"/LeicesterCity"+'/*')
     print("LeicesterCity {}번째 이미지까지 성공".format(i+1))
        
  elif 'CrystalPalace' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/CrystalPalace", 'CrystalPalace_' + '{0:03d}.jpg'.format(i)))
     CrystalPalace = glob.glob(path+"/CrystalPalace"+'/*')
     print("CrystalPalace {}번째 이미지까지 성공".format(i+1))
        
  elif 'Southampton' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Southampton", 'Southampton_' + '{0:03d}.jpg'.format(i)))
     Southampton = glob.glob(path+"/Southampton"+'/*')
     print("Southampton {}번째 이미지까지 성공".format(i+1))
        
  elif 'Everton' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/Everton", 'Everton_' + '{0:03d}.jpg'.format(i)))
     Everton = glob.glob(path+"/Everton"+'/*')
     print("Everton {}번째 이미지까지 성공".format(i+1))
        
  elif 'WestHam' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/WestHam", 'WestHam_' + '{0:03d}.jpg'.format(i)))
     WestHam = glob.glob(path+"/WestHam"+'/*')
     print("WestHam {}번째 이미지까지 성공".format(i+1))

  elif 'ManUnited' in files[0]:
     for i,f in enumerate(files):
         os.rename(f, os.path.join(path+"/ManUnited", 'ManUnited_' + '{0:03d}.jpg'.format(i)))
     ManUnited = glob.glob(path+"/ManUnited"+'/*')
     print("ManUnited {}번째 이미지까지 성공".format(i+1))

# %%
path = "./cnn_practice/train"
ManCity = glob.glob(path+"/ManCity" + '/*')
Arsenal = glob.glob(path+"/Arsenal" + '/*')
Brentford = glob.glob(path+"/Brentford" + '/*')
Tottenham = glob.glob(path+"/Tottenham" + '/*')
Newcastle = glob.glob(path+"/Newcastle" + '/*')
LeedsUnited = glob.glob(path+"/LeedsUnited" + '/*')
Chelsea = glob.glob(path+"/Chelsea" + '/*')
Brighton = glob.glob(path+"/Brighton" + '/*')
AstonVilla = glob.glob(path+"/AstonVilla" + '/*')
NottmForest = glob.glob(path+"/NottmForest" + '/*')
Bournemouth = glob.glob(path+"/Bournemouth" + '/*')
Liverpool = glob.glob(path+"/Liverpool" + '/*')
Fulham = glob.glob(path+"/Fulham" + '/*')
Wolves= glob.glob(path+"/Wolves" + '/*')
LeicesterCity= glob.glob(path+"/LeicesterCity" + '/*')
CrystalPalace = glob.glob(path+"/CrystalPalace" + '/*')
Southampton = glob.glob(path+"/Southampton" + '/*')
Everton = glob.glob(path+"/Everton" + '/*')
WestHam = glob.glob(path+"/WestHam" + '/*')
ManUnited = glob.glob(path+"/ManUnited" + '/*')

rename_2(ManCity)
rename_2(Arsenal)
rename_2(Brentford)
rename_2(Tottenham)
rename_2(Newcastle)
rename_2(LeedsUnited)
rename_2(Chelsea)
rename_2(Brighton)
rename_2(AstonVilla)
rename_2(NottmForest)
rename_2(Bournemouth)
rename_2(Liverpool)
rename_2(Fulham)
rename_2(Wolves)
rename_2(LeicesterCity)
rename_2(CrystalPalace)
rename_2(Southampton)
rename_2(Everton)
rename_2(WestHam)
rename_2(ManUnited)
# Out:
# ManCity 104번째 이미지까지 성공
# Arsenal 182번째 이미지까지 성공
# Brentford 26번째 이미지까지 성공
# Tottenham 190번째 이미지까지 성공
# Newcastle 74번째 이미지까지 성공
# LeedsUnited 22번째 이미지까지 성공
# Chelsea 140번째 이미지까지 성공
# Brighton 48번째 이미지까지 성공
# AstonVilla 31번째 이미지까지 성공
# NottmForest 29번째 이미지까지 성공
# Bournemouth 27번째 이미지까지 성공
# Liverpool 114번째 이미지까지 성공
# Fulham 24번째 이미지까지 성공
# Wolves 30번째 이미지까지 성공
# LeicesterCity 161번째 이미지까지 성공
# CrystalPalace 31번째 이미지까지 성공
# Southampton 33번째 이미지까지 성공
# Everton 162번째 이미지까지 성공
# WestHam 131번째 이미지까지 성공
# ManUnited 233번째 이미지까지 성공

# %%
# testset 넘버링

path = "./cnn_practice/test"
ManCity = glob.glob(path+"/ManCity" + '/*')
Arsenal = glob.glob(path+"/Arsenal" + '/*')
Brentford = glob.glob(path+"/Brentford" + '/*')
Tottenham = glob.glob(path+"/Tottenham" + '/*')
Newcastle = glob.glob(path+"/Newcastle" + '/*')
LeedsUnited = glob.glob(path+"/LeedsUnited" + '/*')
Chelsea = glob.glob(path+"/Chelsea" + '/*')
Brighton = glob.glob(path+"/Brighton" + '/*')
AstonVilla = glob.glob(path+"/AstonVilla" + '/*')
NottmForest = glob.glob(path+"/NottmForest" + '/*')
Bournemouth = glob.glob(path+"/Bournemouth" + '/*')
Liverpool = glob.glob(path+"/Liverpool" + '/*')
Fulham = glob.glob(path+"/Fulham" + '/*')
Wolves= glob.glob(path+"/Wolves" + '/*')
LeicesterCity= glob.glob(path+"/LeicesterCity" + '/*')
CrystalPalace = glob.glob(path+"/CrystalPalace" + '/*')
Southampton = glob.glob(path+"/Southampton" + '/*')
Everton = glob.glob(path+"/Everton" + '/*')
WestHam = glob.glob(path+"/WestHam" + '/*')
ManUnited = glob.glob(path+"/ManUnited" + '/*')

rename_2(ManCity)
rename_2(Arsenal)
rename_2(Brentford)
rename_2(Tottenham)
rename_2(Newcastle)
rename_2(LeedsUnited)
rename_2(Chelsea)
rename_2(Brighton)
rename_2(AstonVilla)
rename_2(NottmForest)
rename_2(Bournemouth)
rename_2(Liverpool)
rename_2(Fulham)
rename_2(Wolves)
rename_2(LeicesterCity)
rename_2(CrystalPalace)
rename_2(Southampton)
rename_2(Everton)
rename_2(WestHam)
rename_2(ManUnited)
# Out:
# ManCity 49번째 이미지까지 성공
# Arsenal 95번째 이미지까지 성공
# Brentford 14번째 이미지까지 성공
# Tottenham 94번째 이미지까지 성공
# Newcastle 38번째 이미지까지 성공
# LeedsUnited 10번째 이미지까지 성공
# Chelsea 69번째 이미지까지 성공
# Brighton 26번째 이미지까지 성공
# AstonVilla 11번째 이미지까지 성공
# NottmForest 14번째 이미지까지 성공
# Bournemouth 12번째 이미지까지 성공
# Liverpool 62번째 이미지까지 성공
# Fulham 12번째 이미지까지 성공
# Wolves 13번째 이미지까지 성공
# LeicesterCity 82번째 이미지까지 성공
# CrystalPalace 16번째 이미지까지 성공
# Southampton 17번째 이미지까지 성공
# Everton 80번째 이미지까지 성공
# WestHam 66번째 이미지까지 성공
# ManUnited 113번째 이미지까지 성공

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
batch_size = 16
img_height = 180
img_width = 180

data_dir = './cnn_practice/train/'

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2, #training:validation set의 비율이 80:20
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1792 files belonging to 20 classes.
# Using 1434 files for training.

# %%
batch_size = 32
img_height = 180
img_width = 180

soccer_dir = './cnn_practice(TEST, TRAIN X)/'

train_ds_soccer = tf.keras.preprocessing.image_dataset_from_directory(
  soccer_dir,
  validation_split=0.2, #training:validation set의 비율이 80:20
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1804 files belonging to 20 classes.
# Using 1444 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1792 files belonging to 20 classes.
# Using 358 files for validation.

# %%
val_ds_soccer = tf.keras.preprocessing.image_dataset_from_directory(
  soccer_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1804 files belonging to 20 classes.
# Using 360 files for validation.

# %%
class_names = train_ds.class_names 
# 데이터셋의 클래스 이름을 class_names에 저장한다. 알파벳 순서의 디렉토리 이름에 해당한다.
print(class_names)

# 실행결과
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
# Out:
# ['Arsenal', 'AstonVilla', 'Bournemouth', 'Brentford', 'Brighton', 'Chelsea', 'CrystalPalace', 'Everton', 'Fulham', 'LeedsUnited', 'LeicesterCity', 'Liverpool', 'ManCity', 'ManUnited', 'Newcastle', 'NottmForest', 'Southampton', 'Tottenham', 'WestHam', 'Wolves']

# %%
class_names = train_ds_soccer.class_names 
# 데이터셋의 클래스 이름을 class_names에 저장한다. 알파벳 순서의 디렉토리 이름에 해당한다.
print(class_names)

# 실행결과
# ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']
# Out:
# ['Arsenal logo', 'AstonVilla logo', 'Bournemouth logo', 'Brentford logo', 'Brighton logo', 'Chelsea logo', 'CrystalPalace logo', 'Everton logo', 'Fulham logo', 'LeedsUnited logo', 'LeicesterCity logo', 'Liverpool logo', 'ManCity logo', 'ManUnited logo', 'Newcastle logo', 'NottmForest logo', 'Southampton logo', 'Tottenham logo', 'WestHam logo', 'Wolves logo']

# %%
for image_batch, labels_batch in train_ds_soccer:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# (16, 180, 180, 3) shape 텐서
# Out:
# (32, 180, 180, 3)
# (32,)

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)
# 색의 값 0 ~ 255 --> 0 ~ 1로 표준화

# %%
num_classes = 20

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# 모델 내에 표준화 layer를 추가하는 방식

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 20)                2580
#
# ...
# Total params: 3,991,220
# Trainable params: 3,991,220
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 10
history = model.fit(x = train_ds_soccer,
                   validation_data=val_ds_soccer,
                   epochs=epochs)
# Out:
# Epoch 1/10
# 46/46 [==============================] - 14s 298ms/step - loss: 2.1617 - accuracy: 0.3850 - val_loss: 1.4955 - val_accuracy: 0.5750
# Epoch 2/10
# 46/46 [==============================] - 13s 277ms/step - loss: 1.0102 - accuracy: 0.7140 - val_loss: 1.1161 - val_accuracy: 0.6833
# Epoch 3/10
# 46/46 [==============================] - 13s 283ms/step - loss: 0.5209 - accuracy: 0.8511 - val_loss: 0.9138 - val_accuracy: 0.7583
# Epoch 4/10
# 46/46 [==============================] - 13s 283ms/step - loss: 0.3439 - accuracy: 0.8927 - val_loss: 0.8947 - val_accuracy: 0.7611
# Epoch 5/10
# 46/46 [==============================] - 15s 331ms/step - loss: 0.2004 - accuracy: 0.9494 - val_loss: 0.8051 - val_accuracy: 0.8028
# Epoch 6/10
# 46/46 [==============================] - 16s 355ms/step - loss: 0.1096 - accuracy: 0.9681 - val_loss: 0.9475 - val_accuracy: 0.7833
# Epoch 7/10
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds_soccer.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
              
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  dense_3 (Dense)             (None, 20)                2580
#
# ...
# Total params: 3,991,220
# Trainable params: 3,991,220
# ...

# %%
epochs = 15
history = model.fit(
  train_ds_soccer,
  validation_data=val_ds_soccer,
  epochs=epochs
)
# Out:
# Epoch 1/15
# 46/46 [==============================] - 29s 603ms/step - loss: 2.1144 - accuracy: 0.3843 - val_loss: 1.6763 - val_accuracy: 0.5528
# Epoch 2/15
# 46/46 [==============================] - 27s 579ms/step - loss: 1.3508 - accuracy: 0.6080 - val_loss: 1.2275 - val_accuracy: 0.6833
# Epoch 3/15
# 46/46 [==============================] - 24s 521ms/step - loss: 0.9913 - accuracy: 0.7361 - val_loss: 0.9731 - val_accuracy: 0.7556
# Epoch 4/15
# 46/46 [==============================] - 24s 519ms/step - loss: 0.7804 - accuracy: 0.7839 - val_loss: 0.8822 - val_accuracy: 0.7639
# Epoch 5/15
# 46/46 [==============================] - 24s 517ms/step - loss: 0.6246 - accuracy: 0.8234 - val_loss: 0.7030 - val_accuracy: 0.8194
# Epoch 6/15
# 46/46 [==============================] - 24s 522ms/step - loss: 0.4749 - accuracy: 0.8698 - val_loss: 0.7929 - val_accuracy: 0.7889
# Epoch 7/15
# ...

# %%
icon_path = './cnn_practice/test/Wolves/Wolves_000.jpg'

img = keras.preprocessing.image.load_img(
    icon_path, target_size=(img_height, img_width)
)

img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 214ms/step
# This image most likely belongs to Wolves logo with a 96.15 percent confidence.

# %%
test_soccer_dir = './cnn_practice/test/'

test_ds_soccer = tf.keras.preprocessing.image_dataset_from_directory(
  test_soccer_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 893 files belonging to 20 classes.

# %%
test_soccer_dir = './cnn_practice(TEST, TRAIN X)/'

test_ds_soccer = tf.keras.preprocessing.image_dataset_from_directory(
  test_soccer_dir,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 1804 files belonging to 20 classes.

# %%
plt.figure(figsize=(12, 12))

test_class_names = test_ds_soccer.class_names 

for images, labels in test_ds_soccer.take(1):
  for i in range(9):
    img = images[i]
    img_array = keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0) # Create a batch

    predictions = model.predict(img_array)
    score = tf.nn.softmax(predictions[0])
    ax = plt.subplots(constrained_layout=True)
    ax = plt.subplot(3, 3, i + 1)
    
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(test_class_names[labels[i]])
    plt.xlabel("{} with a \n{:.2f} percent confidence".format(class_names[np.argmax(score)], 100 * np.max(score)), fontsize=12)
# Out:
# ...
# 1/1 [==============================] - 0s 16ms/step
